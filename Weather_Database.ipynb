# %%
#add dependencies
import random
import numpy as np
import pandas as pd
#matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import timeit 
import time
from datetime import datetime
from scipy.stats import linregress
from citipy import citipy

# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
#gmaps dependencies
import gmaps
# Configure gmaps to use your Google API key.
from config import g_key
gmaps.configure(api_key=g_key)

# %%
#Create a new set of 2,000 random latitudes and longitudes.
#create latitude
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
#create longitude
lngs = np.random.uniform(low=-180.000, high=180.000,size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#list of cities
cities = []
#identify nearest city
for coordinate in coordinates:
    city = (citipy.nearest_city(coordinate[0], coordinate[1]).city_name)
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"] 
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
      
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description, 
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
#city_description = city_weather["coord"]["weather"]["description"]
#"Current Description": city_description,
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | poya
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | rio gallegos
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | tres arroyos
# Processing Record 7 of Set 1 | miram shah
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | saint-augustin
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | kaeo
# Processing Record 17 of Set 1 | zyryanka
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | hami
# Processing Record 20 of Set 1 | ancud
# Processing Record 21 of Set 1 | bonthe
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | narsaq
# Processing Record 24 of Set 1 | teknaf
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | aromashevo
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | hargeysa
# Processing Record 32 of Set 1 | calama
# Processing Record 33 of Set 1 | berlevag
# Processing Record 34 of Set 1 | nagod
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | beringovskiy
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | sai buri
# Processing Record 43 of Set 1 | beckley
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | grindavik
# Processing Record 49 of Set 1 | faya
# Processing Record 50 of Set 1 | rio muerto
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | tailai
# Processing Record 3 of Set 2 | fort nelson
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | merrill
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | evensk
# Processing Record 8 of Set 2 | marathon
# Processing Record 9 of Set 2 | amargosa
# Processing Record 10 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 2 | nizhniy kuranakh
# Processing Record 12 of Set 2 | lakatoro
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | anaconda
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 2 | sorland
# Processing Record 19 of Set 2 | mirnyy
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | santa vitoria do palmar
# Processing Record 22 of Set 2 | phuket
# Processing Record 23 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 2 | novobessergenevka
# Processing Record 25 of Set 2 | thunder bay
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 2 | raga
# Processing Record 29 of Set 2 | vostok
# Processing Record 30 of Set 2 | gizo
# Processing Record 31 of Set 2 | yerkoy
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | richards bay
# Processing Record 34 of Set 2 | jiuquan
# Processing Record 35 of Set 2 | santa cruz cabralia
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | winnemucca
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | salalah
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | wahiawa
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | dongsheng
# Processing Record 47 of Set 2 | aberdeen
# Processing Record 48 of Set 2 | saint-joseph
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 3 | rio bonito
# Processing Record 5 of Set 3 | luderitz
# Processing Record 6 of Set 3 | pasir gudang
# Processing Record 7 of Set 3 | khartoum
# Processing Record 8 of Set 3 | cockburn town
# Processing Record 9 of Set 3 | sao miguel do araguaia
# Processing Record 10 of Set 3 | nishihara
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | batagay-alyta
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | porto velho
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | haines junction
# Processing Record 18 of Set 3 | north bend
# Processing Record 19 of Set 3 | los llanos de aridane
# Processing Record 20 of Set 3 | taltal
# Processing Record 21 of Set 3 | sault sainte marie
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 3 | mataura
# Processing Record 27 of Set 3 | jasper
# Processing Record 28 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | constantine
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | uyuni
# Processing Record 34 of Set 3 | hobyo
# Processing Record 35 of Set 3 | szamotuly
# Processing Record 36 of Set 3 | amapa
# Processing Record 37 of Set 3 | korntal-munchingen
# City not found. Skipping...
# Processing Record 38 of Set 3 | constitucion
# Processing Record 39 of Set 3 | korla
# Processing Record 40 of Set 3 | tabou
# Processing Record 41 of Set 3 | florida
# Processing Record 42 of Set 3 | umm jarr
# City not found. Skipping...
# Processing Record 43 of Set 3 | hirara
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | port augusta
# Processing Record 46 of Set 3 | ginir
# Processing Record 47 of Set 3 | kokopo
# Processing Record 48 of Set 3 | san cristobal
# Processing Record 49 of Set 3 | lompoc
# Processing Record 50 of Set 3 | padang
# Processing Record 1 of Set 4 | labuhan
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | shingu
# Processing Record 5 of Set 4 | atuona
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | hobart
# Processing Record 8 of Set 4 | elizabeth city
# Processing Record 9 of Set 4 | south jordan
# Processing Record 10 of Set 4 | cancun
# Processing Record 11 of Set 4 | erzin
# Processing Record 12 of Set 4 | alice springs
# Processing Record 13 of Set 4 | carutapera
# Processing Record 14 of Set 4 | sitka
# Processing Record 15 of Set 4 | qingdao
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | baikunthpur
# Processing Record 19 of Set 4 | carlyle
# Processing Record 20 of Set 4 | jand
# Processing Record 21 of Set 4 | bubaque
# Processing Record 22 of Set 4 | hearst
# Processing Record 23 of Set 4 | sosnogorsk
# Processing Record 24 of Set 4 | broome
# Processing Record 25 of Set 4 | flinders
# Processing Record 26 of Set 4 | copperas cove
# Processing Record 27 of Set 4 | aykhal
# Processing Record 28 of Set 4 | tateyama
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 4 | mataram
# Processing Record 32 of Set 4 | baruun-urt
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | kijang
# Processing Record 35 of Set 4 | nantucket
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | myitkyina
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | vestmannaeyjar
# Processing Record 40 of Set 4 | martinsburg
# Processing Record 41 of Set 4 | samarai
# Processing Record 42 of Set 4 | naantali
# Processing Record 43 of Set 4 | karratha
# Processing Record 44 of Set 4 | dawei
# Processing Record 45 of Set 4 | san-pedro
# Processing Record 46 of Set 4 | haapiti
# Processing Record 47 of Set 4 | poum
# Processing Record 48 of Set 4 | nantong
# Processing Record 49 of Set 4 | caxito
# Processing Record 50 of Set 4 | kartaly
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | axim
# Processing Record 3 of Set 5 | fonte boa
# Processing Record 4 of Set 5 | the pas
# Processing Record 5 of Set 5 | noyakert
# Processing Record 6 of Set 5 | nome
# Processing Record 7 of Set 5 | gushikawa
# Processing Record 8 of Set 5 | zirandaro
# Processing Record 9 of Set 5 | comitancillo
# Processing Record 10 of Set 5 | almazar
# Processing Record 11 of Set 5 | dobson
# Processing Record 12 of Set 5 | nyurba
# Processing Record 13 of Set 5 | sobolevo
# Processing Record 14 of Set 5 | darnah
# Processing Record 15 of Set 5 | uvira
# Processing Record 16 of Set 5 | chimoio
# Processing Record 17 of Set 5 | santa rosa
# Processing Record 18 of Set 5 | milyutinskaya
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | abha
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | linxia
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | atasu
# Processing Record 27 of Set 5 | denpasar
# Processing Record 28 of Set 5 | sao sebastiao
# Processing Record 29 of Set 5 | obo
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | guerrero negro
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | ilulissat
# Processing Record 35 of Set 5 | ixtapa
# Processing Record 36 of Set 5 | aranos
# Processing Record 37 of Set 5 | san matias
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | alassio
# Processing Record 40 of Set 5 | butaritari
# Processing Record 41 of Set 5 | tasiilaq
# Processing Record 42 of Set 5 | tome
# Processing Record 43 of Set 5 | tonj
# Processing Record 44 of Set 5 | mar del plata
# Processing Record 45 of Set 5 | pio xii
# Processing Record 46 of Set 5 | husavik
# Processing Record 47 of Set 5 | baraboo
# Processing Record 48 of Set 5 | isangel
# Processing Record 49 of Set 5 | la palma
# Processing Record 50 of Set 5 | tahta
# Processing Record 1 of Set 6 | nalut
# Processing Record 2 of Set 6 | vila velha
# Processing Record 3 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 6 | champerico
# Processing Record 5 of Set 6 | iraray
# Processing Record 6 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 6 | loa janan
# Processing Record 8 of Set 6 | vao
# Processing Record 9 of Set 6 | heihe
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | peterhead
# Processing Record 13 of Set 6 | georgetown
# Processing Record 14 of Set 6 | vologda
# Processing Record 15 of Set 6 | chapais
# Processing Record 16 of Set 6 | ampanihy
# Processing Record 17 of Set 6 | kaithal
# Processing Record 18 of Set 6 | avarua
# Processing Record 19 of Set 6 | cefa
# Processing Record 20 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 6 | maragogi
# Processing Record 22 of Set 6 | pasewalk
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 25 of Set 6 | bjelovar
# Processing Record 26 of Set 6 | port lincoln
# Processing Record 27 of Set 6 | moron
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | ust-koksa
# Processing Record 30 of Set 6 | praia da vitoria
# Processing Record 31 of Set 6 | nouadhibou
# Processing Record 32 of Set 6 | vila franca do campo
# Processing Record 33 of Set 6 | sunamganj
# City not found. Skipping...
# Processing Record 34 of Set 6 | port-cartier
# Processing Record 35 of Set 6 | cap malheureux
# Processing Record 36 of Set 6 | davila
# Processing Record 37 of Set 6 | paka
# Processing Record 38 of Set 6 | chicama
# Processing Record 39 of Set 6 | lixourion
# Processing Record 40 of Set 6 | nuuk
# Processing Record 41 of Set 6 | johnstown
# Processing Record 42 of Set 6 | yuancheng
# Processing Record 43 of Set 6 | awjilah
# Processing Record 44 of Set 6 | dunedin
# Processing Record 45 of Set 6 | half moon bay
# Processing Record 46 of Set 6 | chuy
# Processing Record 47 of Set 6 | rio grande
# Processing Record 48 of Set 6 | sompeta
# Processing Record 49 of Set 6 | chokurdakh
# Processing Record 50 of Set 6 | rawson
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | meadow lake
# Processing Record 3 of Set 7 | nanortalik
# Processing Record 4 of Set 7 | svetlogorsk
# Processing Record 5 of Set 7 | kresttsy
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | waverley
# Processing Record 8 of Set 7 | vardo
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | kudahuvadhoo
# Processing Record 11 of Set 7 | harper
# Processing Record 12 of Set 7 | ferme-neuve
# Processing Record 13 of Set 7 | bahia blanca
# Processing Record 14 of Set 7 | oytal
# Processing Record 15 of Set 7 | roebourne
# Processing Record 16 of Set 7 | gander
# Processing Record 17 of Set 7 | ahipara
# Processing Record 18 of Set 7 | la ronge
# Processing Record 19 of Set 7 | boa vista
# Processing Record 20 of Set 7 | geraldton
# Processing Record 21 of Set 7 | dover
# Processing Record 22 of Set 7 | verkhniy tagil
# Processing Record 23 of Set 7 | tukums
# Processing Record 24 of Set 7 | muli
# Processing Record 25 of Set 7 | senador guiomard
# Processing Record 26 of Set 7 | iqaluit
# Processing Record 27 of Set 7 | barra do garcas
# Processing Record 28 of Set 7 | buchanan
# Processing Record 29 of Set 7 | yuxia
# Processing Record 30 of Set 7 | mutoko
# Processing Record 31 of Set 7 | arman
# Processing Record 32 of Set 7 | puri
# Processing Record 33 of Set 7 | port hardy
# Processing Record 34 of Set 7 | praia
# Processing Record 35 of Set 7 | sembakung
# Processing Record 36 of Set 7 | doka
# Processing Record 37 of Set 7 | tillabery
# City not found. Skipping...
# Processing Record 38 of Set 7 | assiniboia
# Processing Record 39 of Set 7 | kamenka
# Processing Record 40 of Set 7 | tagab
# Processing Record 41 of Set 7 | petropavlovka
# Processing Record 42 of Set 7 | nelson bay
# Processing Record 43 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 7 | araouane
# Processing Record 45 of Set 7 | xiongzhou
# Processing Record 46 of Set 7 | weligama
# Processing Record 47 of Set 7 | udachnyy
# Processing Record 48 of Set 7 | slave lake
# Processing Record 49 of Set 7 | ketchikan
# Processing Record 50 of Set 7 | itaquyry
# Processing Record 1 of Set 8 | porosozero
# Processing Record 2 of Set 8 | loveland
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | umm lajj
# Processing Record 6 of Set 8 | kuroiso
# Processing Record 7 of Set 8 | kazanskaya
# Processing Record 8 of Set 8 | koumac
# Processing Record 9 of Set 8 | antibes
# Processing Record 10 of Set 8 | maniitsoq
# Processing Record 11 of Set 8 | erenhot
# Processing Record 12 of Set 8 | hervey bay
# Processing Record 13 of Set 8 | santa rosalia
# Processing Record 14 of Set 8 | santiago del estero
# Processing Record 15 of Set 8 | okhotsk
# Processing Record 16 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 17 of Set 8 | pacific grove
# Processing Record 18 of Set 8 | koutsouras
# Processing Record 19 of Set 8 | kimbe
# Processing Record 20 of Set 8 | dubbo
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | shagonar
# Processing Record 23 of Set 8 | pokhara
# Processing Record 24 of Set 8 | sonari
# Processing Record 25 of Set 8 | bolu
# Processing Record 26 of Set 8 | mecca
# Processing Record 27 of Set 8 | shache
# Processing Record 28 of Set 8 | meulaboh
# Processing Record 29 of Set 8 | zaltan
# Processing Record 30 of Set 8 | warrnambool
# Processing Record 31 of Set 8 | bara
# Processing Record 32 of Set 8 | bonavista
# Processing Record 33 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 36 of Set 8 | beyneu
# Processing Record 37 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 8 | linhai
# Processing Record 39 of Set 8 | paracatu
# Processing Record 40 of Set 8 | taoudenni
# Processing Record 41 of Set 8 | gamba
# Processing Record 42 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | ekhabi
# Processing Record 45 of Set 8 | lagoa
# Processing Record 46 of Set 8 | griffith
# Processing Record 47 of Set 8 | bilibino
# Processing Record 48 of Set 8 | ornskoldsvik
# Processing Record 49 of Set 8 | beipiao
# Processing Record 50 of Set 8 | naze
# Processing Record 1 of Set 9 | yelizovo
# Processing Record 2 of Set 9 | tecpan
# Processing Record 3 of Set 9 | kenai
# Processing Record 4 of Set 9 | deputatskiy
# Processing Record 5 of Set 9 | nurota
# Processing Record 6 of Set 9 | limpapa
# Processing Record 7 of Set 9 | zaraza
# Processing Record 8 of Set 9 | vilhena
# Processing Record 9 of Set 9 | sremska mitrovica
# Processing Record 10 of Set 9 | sarh
# Processing Record 11 of Set 9 | del rio
# Processing Record 12 of Set 9 | kharan
# Processing Record 13 of Set 9 | malambo
# Processing Record 14 of Set 9 | huanren
# Processing Record 15 of Set 9 | namatanai
# Processing Record 16 of Set 9 | abu dhabi
# Processing Record 17 of Set 9 | guben
# Processing Record 18 of Set 9 | qui nhon
# Processing Record 19 of Set 9 | koslan
# Processing Record 20 of Set 9 | pangkalanbuun
# Processing Record 21 of Set 9 | grand gaube
# Processing Record 22 of Set 9 | batagay
# Processing Record 23 of Set 9 | thinadhoo
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | kismayo
# Processing Record 26 of Set 9 | ratnagiri
# Processing Record 27 of Set 9 | komsomolskiy
# Processing Record 28 of Set 9 | jaipur hat
# City not found. Skipping...
# Processing Record 29 of Set 9 | andenes
# Processing Record 30 of Set 9 | manono
# Processing Record 31 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 9 | soyo
# Processing Record 33 of Set 9 | belaya gora
# Processing Record 34 of Set 9 | aginskoye
# Processing Record 35 of Set 9 | nhulunbuy
# Processing Record 36 of Set 9 | namibe
# Processing Record 37 of Set 9 | madan
# Processing Record 38 of Set 9 | ponnani
# Processing Record 39 of Set 9 | abu kamal
# Processing Record 40 of Set 9 | antofagasta
# Processing Record 41 of Set 9 | kirakira
# Processing Record 42 of Set 9 | lata
# Processing Record 43 of Set 9 | outjo
# Processing Record 44 of Set 9 | anloga
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | ascension
# Processing Record 47 of Set 9 | bollnas
# Processing Record 48 of Set 9 | ndioum
# Processing Record 49 of Set 9 | buenaventura
# Processing Record 50 of Set 9 | sao filipe
# Processing Record 1 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 10 | olga
# Processing Record 3 of Set 10 | ariogala
# Processing Record 4 of Set 10 | quebo
# Processing Record 5 of Set 10 | mackay
# Processing Record 6 of Set 10 | hofn
# Processing Record 7 of Set 10 | pochutla
# Processing Record 8 of Set 10 | takoradi
# Processing Record 9 of Set 10 | yerbogachen
# Processing Record 10 of Set 10 | sydney
# Processing Record 11 of Set 10 | bar-le-duc
# Processing Record 12 of Set 10 | henties bay
# Processing Record 13 of Set 10 | ust-kuyga
# Processing Record 14 of Set 10 | chipinge
# Processing Record 15 of Set 10 | kerman
# Processing Record 16 of Set 10 | marawi
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | kununurra
# Processing Record 19 of Set 10 | buin
# Processing Record 20 of Set 10 | ust-ilimsk
# Processing Record 21 of Set 10 | ewa beach
# Processing Record 22 of Set 10 | sangar
# Processing Record 23 of Set 10 | moose factory
# Processing Record 24 of Set 10 | carballo
# Processing Record 25 of Set 10 | kahului
# Processing Record 26 of Set 10 | krasnoselkup
# Processing Record 27 of Set 10 | seoul
# Processing Record 28 of Set 10 | shakawe
# Processing Record 29 of Set 10 | akdepe
# Processing Record 30 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 32 of Set 10 | karwar
# Processing Record 33 of Set 10 | altamont
# Processing Record 34 of Set 10 | ipira
# Processing Record 35 of Set 10 | katangli
# Processing Record 36 of Set 10 | keokuk
# Processing Record 37 of Set 10 | bathsheba
# Processing Record 38 of Set 10 | hohhot
# Processing Record 39 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 10 | villa maria
# Processing Record 41 of Set 10 | kavaratti
# Processing Record 42 of Set 10 | coihaique
# Processing Record 43 of Set 10 | nova olinda do norte
# Processing Record 44 of Set 10 | marshall
# Processing Record 45 of Set 10 | tura
# Processing Record 46 of Set 10 | valley station
# Processing Record 47 of Set 10 | byron bay
# Processing Record 48 of Set 10 | karpathos
# Processing Record 49 of Set 10 | nokaneng
# Processing Record 50 of Set 10 | oranjestad
# Processing Record 1 of Set 11 | anadyr
# Processing Record 2 of Set 11 | roma
# Processing Record 3 of Set 11 | puerto penasco
# Processing Record 4 of Set 11 | solnechnyy
# Processing Record 5 of Set 11 | lukulu
# Processing Record 6 of Set 11 | polunochnoye
# Processing Record 7 of Set 11 | baghdad
# Processing Record 8 of Set 11 | drayton valley
# Processing Record 9 of Set 11 | kloulklubed
# Processing Record 10 of Set 11 | nenjiang
# Processing Record 11 of Set 11 | talcahuano
# Processing Record 12 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 11 | isiro
# Processing Record 14 of Set 11 | yanam
# Processing Record 15 of Set 11 | tamiahua
# Processing Record 16 of Set 11 | ossora
# Processing Record 17 of Set 11 | hambantota
# Processing Record 18 of Set 11 | khovu-aksy
# Processing Record 19 of Set 11 | najran
# Processing Record 20 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 11 | dingle
# Processing Record 22 of Set 11 | nosy varika
# Processing Record 23 of Set 11 | ambon
# Processing Record 24 of Set 11 | nuevo progreso
# Processing Record 25 of Set 11 | sioux lookout
# Processing Record 26 of Set 11 | jalu
# Processing Record 27 of Set 11 | nicoya
# Processing Record 28 of Set 11 | el estor
# Processing Record 29 of Set 11 | norman wells
# Processing Record 30 of Set 11 | riyadh
# Processing Record 31 of Set 11 | alashtar
# City not found. Skipping...
# Processing Record 32 of Set 11 | wakkanai
# Processing Record 33 of Set 11 | balabac
# Processing Record 34 of Set 11 | melekhovskaya
# City not found. Skipping...
# Processing Record 35 of Set 11 | sarangani
# Processing Record 36 of Set 11 | hovd
# Processing Record 37 of Set 11 | sayyan
# Processing Record 38 of Set 11 | alma
# Processing Record 39 of Set 11 | saraland
# Processing Record 40 of Set 11 | miloslavskoye
# Processing Record 41 of Set 11 | usinsk
# Processing Record 42 of Set 11 | havoysund
# Processing Record 43 of Set 11 | aklavik
# Processing Record 44 of Set 11 | armidale
# Processing Record 45 of Set 11 | caruray
# Processing Record 46 of Set 11 | aitape
# Processing Record 47 of Set 11 | gloucester
# Processing Record 48 of Set 11 | mount isa
# Processing Record 49 of Set 11 | barentu
# Processing Record 50 of Set 11 | yumen
# Processing Record 1 of Set 12 | mitsamiouli
# Processing Record 2 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 12 | bongandanga
# Processing Record 4 of Set 12 | starosubkhangulovo
# Processing Record 5 of Set 12 | artyom
# Processing Record 6 of Set 12 | capinopolis
# Processing Record 7 of Set 12 | turangi
# Processing Record 8 of Set 12 | macae
# Processing Record 9 of Set 12 | mananara
# Processing Record 10 of Set 12 | mahibadhoo
# Processing Record 11 of Set 12 | itoigawa
# Processing Record 12 of Set 12 | kaohsiung
# Processing Record 13 of Set 12 | kuybyshevo
# Processing Record 14 of Set 12 | manokwari
# Processing Record 15 of Set 12 | erdenet
# Processing Record 16 of Set 12 | adre
# Processing Record 17 of Set 12 | vila
# Processing Record 18 of Set 12 | vidalia
# Processing Record 19 of Set 12 | masallatah
# Processing Record 20 of Set 12 | sechelt
# Processing Record 21 of Set 12 | florianopolis
# Processing Record 22 of Set 12 | san juan
# Processing Record 23 of Set 12 | maragogipe
# Processing Record 24 of Set 12 | kyra
# Processing Record 25 of Set 12 | saint-pierre
# Processing Record 26 of Set 12 | tazovskiy
# Processing Record 27 of Set 12 | hindupur
# Processing Record 28 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 29 of Set 12 | ayagoz
# Processing Record 30 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 12 | george
# Processing Record 32 of Set 12 | port said
# Processing Record 33 of Set 12 | tadine
# Processing Record 34 of Set 12 | kalmunai
# Processing Record 35 of Set 12 | katsuura
# Processing Record 36 of Set 12 | tommot
# Processing Record 37 of Set 12 | poplar bluff
# Processing Record 38 of Set 12 | tefe
# Processing Record 39 of Set 12 | alofi
# Processing Record 40 of Set 12 | dakar
# Processing Record 41 of Set 12 | saint-georges
# Processing Record 42 of Set 12 | saint anthony
# Processing Record 43 of Set 12 | ambilobe
# Processing Record 44 of Set 12 | ulaangom
# Processing Record 45 of Set 12 | pokrovka
# Processing Record 46 of Set 12 | liwale
# Processing Record 47 of Set 12 | verkhnyaya toyma
# Processing Record 48 of Set 12 | derzhavinsk
# Processing Record 49 of Set 12 | navalmoral de la mata
# Processing Record 50 of Set 12 | lazaro cardenas
# Processing Record 1 of Set 13 | surt
# Processing Record 2 of Set 13 | tual
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | san pedro
# Processing Record 5 of Set 13 | fairlie
# Processing Record 6 of Set 13 | calvinia
# Processing Record 7 of Set 13 | bilma
# Processing Record 8 of Set 13 | olavarria
# Processing Record 9 of Set 13 | dalbandin
# Processing Record 10 of Set 13 | birao
# Processing Record 11 of Set 13 | cayenne
# Processing Record 12 of Set 13 | stolberg
# Processing Record 13 of Set 13 | sindor
# Processing Record 14 of Set 13 | scarborough
# Processing Record 15 of Set 13 | azul
# Processing Record 16 of Set 13 | roald
# Processing Record 17 of Set 13 | itoman
# Processing Record 18 of Set 13 | opuwo
# Processing Record 19 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 13 | waipawa
# Processing Record 21 of Set 13 | marsh harbour
# Processing Record 22 of Set 13 | envira
# Processing Record 23 of Set 13 | warkworth
# Processing Record 24 of Set 13 | sokoto
# Processing Record 25 of Set 13 | wajid
# Processing Record 26 of Set 13 | chateauroux
# Processing Record 27 of Set 13 | ambikapur
# Processing Record 28 of Set 13 | sur
# Processing Record 29 of Set 13 | leh
# Processing Record 30 of Set 13 | tabuk
# Processing Record 31 of Set 13 | oxford
# Processing Record 32 of Set 13 | college park
# Processing Record 33 of Set 13 | puerto baquerizo moreno
# Processing Record 34 of Set 13 | majene
# Processing Record 35 of Set 13 | zhuhai
# Processing Record 36 of Set 13 | tsiroanomandidy
# Processing Record 37 of Set 13 | luganville
# Processing Record 38 of Set 13 | rafai
# Processing Record 39 of Set 13 | richard toll
# City not found. Skipping...
# Processing Record 40 of Set 13 | lere
# Processing Record 41 of Set 13 | tecolutla
# Processing Record 42 of Set 13 | camacha
# Processing Record 43 of Set 13 | peniche
# Processing Record 44 of Set 13 | smithers
# Processing Record 45 of Set 13 | matara
# Processing Record 46 of Set 13 | pimenta bueno
# Processing Record 47 of Set 13 | gogrial
# Processing Record 48 of Set 13 | port hawkesbury
# Processing Record 49 of Set 13 | tatarastii de sus
# City not found. Skipping...
# Processing Record 50 of Set 13 | atar
# Processing Record 1 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 2 of Set 14 | makinsk
# Processing Record 3 of Set 14 | ilawa
# Processing Record 4 of Set 14 | chorozinho
# Processing Record 5 of Set 14 | martinsville
# Processing Record 6 of Set 14 | swan river
# Processing Record 7 of Set 14 | honningsvag
# Processing Record 8 of Set 14 | santa isabel do rio negro
# Processing Record 9 of Set 14 | capitao poco
# Processing Record 10 of Set 14 | havre-saint-pierre
# Processing Record 11 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 14 | zhangjiakou
# Processing Record 13 of Set 14 | muros
# Processing Record 14 of Set 14 | tezu
# Processing Record 15 of Set 14 | walvis bay
# Processing Record 16 of Set 14 | bosaso
# Processing Record 17 of Set 14 | den helder
# Processing Record 18 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 14 | nagaur
# Processing Record 20 of Set 14 | novoagansk
# Processing Record 21 of Set 14 | morros
# Processing Record 22 of Set 14 | uk
# City not found. Skipping...
# Processing Record 23 of Set 14 | hebertville
# City not found. Skipping...
# Processing Record 24 of Set 14 | aksarka
# Processing Record 25 of Set 14 | outlook
# Processing Record 26 of Set 14 | melbu
# Processing Record 27 of Set 14 | fairbanks
# Processing Record 28 of Set 14 | makurdi
# Processing Record 29 of Set 14 | beboto
# Processing Record 30 of Set 14 | college
# Processing Record 31 of Set 14 | avera
# Processing Record 32 of Set 14 | shimoda
# Processing Record 33 of Set 14 | koster
# Processing Record 34 of Set 14 | sola
# Processing Record 35 of Set 14 | sinnamary
# Processing Record 36 of Set 14 | mizdah
# Processing Record 37 of Set 14 | salina cruz
# Processing Record 38 of Set 14 | porto novo
# Processing Record 39 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 14 | chibombo
# Processing Record 41 of Set 14 | juneau
# Processing Record 42 of Set 14 | bikramganj
# Processing Record 43 of Set 14 | bandarbeyla
# Processing Record 44 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 45 of Set 14 | moss vale
# Processing Record 46 of Set 14 | iralaya
# Processing Record 47 of Set 14 | sharlyk
# Processing Record 48 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 14 | bairiki
# Processing Record 50 of Set 14 | jeremie
# Processing Record 1 of Set 15 | pathein
# Processing Record 2 of Set 15 | andilamena
# Processing Record 3 of Set 15 | kilifi
# Processing Record 4 of Set 15 | sikasso
# Processing Record 5 of Set 15 | charagua
# Processing Record 6 of Set 15 | puerto del rosario
# Processing Record 7 of Set 15 | beaverlodge
# Processing Record 8 of Set 15 | ushtobe
# Processing Record 9 of Set 15 | kinablangan
# Processing Record 10 of Set 15 | margate
# Processing Record 11 of Set 15 | zhezkazgan
# Processing Record 12 of Set 15 | pangnirtung
# Processing Record 13 of Set 15 | shirokiy
# Processing Record 14 of Set 15 | prince rupert
# Processing Record 15 of Set 15 | srednyaya akhtuba
# Processing Record 16 of Set 15 | ugoofaaru
# Processing Record 17 of Set 15 | thonon-les-bains
# Processing Record 18 of Set 15 | malakal
# Processing Record 19 of Set 15 | toora-khem
# Processing Record 20 of Set 15 | bandarban
# Processing Record 21 of Set 15 | jardim
# Processing Record 22 of Set 15 | dezful
# Processing Record 23 of Set 15 | matagami
# Processing Record 24 of Set 15 | mineiros
# Processing Record 25 of Set 15 | jacmel
# Processing Record 26 of Set 15 | chimbote
# Processing Record 27 of Set 15 | zhigalovo
# Processing Record 28 of Set 15 | tessalit
# Processing Record 29 of Set 15 | lasa
# Processing Record 30 of Set 15 | cozumel
# Processing Record 31 of Set 15 | rio brilhante
# Processing Record 32 of Set 15 | diego de almagro
# Processing Record 33 of Set 15 | bemidji
# Processing Record 34 of Set 15 | awbari
# Processing Record 35 of Set 15 | fengzhen
# Processing Record 36 of Set 15 | pasighat
# Processing Record 37 of Set 15 | changqing
# Processing Record 38 of Set 15 | northam
# Processing Record 39 of Set 15 | yining
# Processing Record 40 of Set 15 | sao paulo de olivenca
# Processing Record 41 of Set 15 | rochegda
# Processing Record 42 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 15 | linares
# Processing Record 44 of Set 15 | rocha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Poya      NC -21.3500  165.1500     70.18        81          99
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     87.76        58          20
# 2     Rio Gallegos      AR -51.6226  -69.2181     42.85        70          40
# 3      Port Alfred      ZA -33.5906   26.8910     62.19        82           1
# 4            Bluff      NZ -46.6000  168.3333     49.68        84          63
# 5     Tres Arroyos      AR -38.3739  -60.2798     61.50        25           0
# 6       Miram Shah      PK  33.0086   70.0697     82.11        20          44
# 7          Rikitea      PF -23.1203 -134.9692     77.67        72          51
# 8          Te Anau      NZ -45.4167  167.7167     42.85        95          19
# 9        Carnarvon      AU -24.8667  113.6333     66.27        77          59
#
#    Wind Speed Current Description                 Date
# 0        6.33     overcast clouds  2022-04-27 16:51:21
# 1       17.27          few clouds  2022-04-27 16:50:04
# 2       21.85    scattered clouds  2022-04-27 16:47:07
# 3       14.92           clear sky  2022-04-27 16:51:36
# 4        5.95       broken clouds  2022-04-27 16:46:24
# 5        8.70           clear sky  2022-04-27 16:51:36
# 6        1.23    scattered clouds  2022-04-27 16:51:37
# 7       24.00       broken clouds  2022-04-27 16:48:50
# 8        1.25          few clouds  2022-04-27 16:51:37
# 9       10.36       broken clouds  2022-04-27 16:50:04

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
